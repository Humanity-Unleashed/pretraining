# %%
from humun_benchmark.prompt import InstructPrompt
import pickle as pkl
import pandas as pd

# %% [markdown]
# After running `python humun_benchmark/generate.py` + desired flags, a .pkl will be saved (by default to `data/prompts/file.pkl`) that contains the prompt instance with related info inside, including results.

# %%
# Replace with your pickle file's path
file_path = 'data/prompts/20241211_233348.pkl' 

# Read the pickle file
with open(file_path, 'rb') as file:
    prompt = pkl.load(file)

# %%
print(prompt.prompt_text)
# Out:
# <task>
# You are an economic time-series forecasting expert. Predict the values at the forecast timestamps given the historical data provided.
#
# Only provide the forecast in your response in the format (timestamp, value) in between <forecast> and </forecast> tags. Don't include any other information/comments in your response.
# </task>
# <history>
# (1990-01-01, 6.5)
# (1990-02-01, 6.5)
# (1990-03-01, 5.7)
# (1990-04-01, 6.6)
# (1990-05-01, 6.0)
# (1990-06-01, 7.1)
# (1990-07-01, 6.0)
# (1990-08-01, 6.7)
# (1990-09-01, 7.3)
# (1990-10-01, 7.2)
# (1990-11-01, 6.3)
# (1990-12-01, 6.4)
# (1991-01-01, 6.6)
# (1991-02-01, 7.5)
# (1991-03-01, 7.1)
# (1991-04-01, 6.6)
# (1991-05-01, 6.5)
# (1991-06-01, 7.7)
# (1991-07-01, 6.6)
# (1991-08-01, 7.1)
# (1991-09-01, 6.8)
# (1991-10-01, 6.2)
# (1991-11-01, 6.0)
# (1991-12-01, 6.2)
# (1992-01-01, 6.9)
# (1992-02-01, 6.9)
# (1992-03-01, 6.3)
# (1992-04-01, 5.6)
# (1992-05-01, 5.9)
# (1992-06-01, 7.2)
# (1992-07-01, 6.5)
# (1992-08-01, 6.8)
# ...

# %%
prompt.results_df
# Out:
#           date  forecast_1  forecast_2
# 0   2017-10-01         4.9         5.1
# 1   2017-11-01         4.5         4.9
# 2   2017-12-01         4.1         4.4
# 3   2018-01-01         3.8         4.3
# 4   2018-02-01         3.5         4.2
# ..         ...         ...         ...
# 77  2024-03-01         0.6         3.6
# 78  2024-04-01         0.5         3.5
# 79  2024-05-01         0.5         3.4
# 80  2024-06-01         0.6         4.1
# 81  2024-07-01         0.5         4.0
#
# [82 rows x 3 columns]
